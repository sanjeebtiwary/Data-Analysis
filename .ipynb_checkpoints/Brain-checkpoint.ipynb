# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Project\Brain Stroke\data.csv')
df
# Out:
#     subject_number completed_visit_status htn_patient_medical_history  \
# 0            S0011             INELIGIBLE                         YES
# 1            S0030              COMPLETED                         YES
# 2            S0033               EXCLUDED                          no
# 3            S0044              COMPLETED                          NO
# 4            S0064              COMPLETED                         YES
# ..             ...                    ...                         ...
# 167          S0412   EXCLUDED PENDING PCP                          NO
# 168          S0413               EXCLUDED                         YES
# 169          S0414               EXCLUDED                         YES
# 170          S0418       WITHDREW CONSENT                         NaN
# 171          S0425               EXCLUDED                         NaN
#
#        group       group2  age  height/m    mass/kg        bmi gender  ...  \
# ...

# %%
import seaborn as sns
