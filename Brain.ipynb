# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('D:\Project\Brain Stroke\Preprocessing_Brainstroke.xlsx')
df
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
import seaborn as sns

# %%
result = df.pivot(index='id',columns='heart_disease',values='stroke')
print(result)
# Out:
# heart_disease    0    1
# id
# 1              NaN  0.0
# 4              0.0  NaN
# 6              0.0  NaN
# 7              0.0  NaN
# 8              0.0  NaN
# ...            ...  ...
# 72938          0.0  NaN
# 72939          0.0  NaN
# 72940          0.0  NaN
# 72941          0.0  NaN
# 72943          0.0  NaN
#
# [43400 rows x 2 columns]

# %%
labels = (np.asarray(["{0} \n {1:.2f}".format(symb,value)
                      for symb, value in zip(symbol.flatten(),
                                               perchange.flatten())])
         ).reshape(6,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 sns.heatmap(result,annot=labels,fmt="",cmap='RdYlGn',linewidths=0.30,ax=ax)
#       3 # Display the Pharma Sector Heatmap
#       4 plt.show()
#
# NameError: name 'labels' is not defined
